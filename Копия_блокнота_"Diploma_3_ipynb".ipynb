# %% [markdown]
# <a href="https://colab.research.google.com/github/StasYu/Code-samples/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Diploma_3_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import plotly.express as px
import plotly.graph_objects as go
import scipy.stats as stats
from collections import Counter

# %%
df = pd.read_csv('megafon.csv')#ссчитываем данные в датафрейм

# %%
Counter(df['Q1'])#Смотрим на уникальные значения так как список значений условно дискретный
# Out:
# Counter({'5': 234,
#          '1': 532,
#          '8': 291,
#          '2': 168,
#          '3': 325,
#          '9': 238,
#          '10': 846,
#          '7': 200,
#          '4': 123,
#          '11': 1,
#          '6': 101,
#          '2, 9': 1,
#          '0': 10,
#          '1, 3': 2,
#          '19': 1,
#          '15': 1,
#          nan: 2,
#          '1, 6': 1,
#          '***** ** ***': 1,
#          '3 - дер.Ширяево Волоколамского района, 9 - в Москве': 1,
#          '10, 9': 1,
#          'Чем даль ше,тем лучше.Спасибо за ваш труд.Оценка 10 !': 1,
#          'ОЦЕНКА-3/НЕВАЖНО/': 1,
#          'Отвратительно': 1,
#          'Я ценой услуг не удовлетворен': 1,
#          'Пока не понял': 1,
#          '3, 9': 1,
#          '5, 6': 2,
#          '0, 1, 5': 1,
#          '5, 7': 1,
#          'Hi': 1,
#          '4. Тульская область Заокский район. Романовские дачи связи почти нет': 1,
#          'Немагу дать атценку денги незашто снимаеть скоро выклучаю': 1,
#          '10, 50': 1,
#          'Очень  хорошо. Обслуживания  я довольно. Спасибо вам.555': 1,
#          '?': 1,
#          'Поохое': 1,
#          'Когда в Москве-10 а когда в калужской области в деревне Бели-1': 1,
#          'Нет': 2,
#          'Да': 2,
#          'Ужасно': 1,
#          '3 тройка, связь отвратительная, жалко платить за такой тарив': 1,
#          'Чдтчдтччдтччч': 1,
#          '3, 7': 1,
#          '20, 89031081392': 1,
#          '1, 8': 1,
#          'Без з': 1,
#          '10, 5': 1,
#          '2, 5': 1,
#          'Я в Смол. Области живу сейчас, не пользуюсь телефоном совсем': 1})

# %%
#фильтруем значения колонки Q1
df = df[
    (df['Q1'] == '1') | (df['Q1'] == '2') | (df['Q1'] == '3') |
    (df['Q1'] == '4') | (df['Q1'] == '5') | (df['Q1'] == '6') |
    (df['Q1'] == '7') | (df['Q1'] == '8') | (df['Q1'] == '9') |
    (df['Q1'] == '10')
        ]

# %%
Counter(df['Q2'])
# Out:
# Counter({nan: 1743,
#          '4': 170,
#          '3': 190,
#          '2, 3, 4': 11,
#          '4, 5': 30,
#          '1, 3, 4': 76,
#          '1, 3, 4, 5': 40,
#          '1, 3': 121,
#          '3, 4': 85,
#          '1, 2': 22,
#          '3, 5': 8,
#          '1': 168,
#          '7': 64,
#          '1, 4': 56,
#          '1, 2, 3, 4, 5': 27,
#          '2, 3': 12,
#          '1, 2, 3, 4': 18,
#          '2, 3, 4, 5': 3,
#          '3, 4, 5': 45,
#          '1, 2, 5': 3,
#          '1, 5': 7,
#          '1, 2, 4': 11,
#          '6': 10,
#          '1, 4, 5': 27,
#          '1, 2, 3': 44,
#          '2, 5': 1,
#          '2, 4, 5': 2,
#          '1, 2, 7': 1,
#          '5': 9,
#          '2': 11,
#          '1, 2, 3, 4, 5, 6': 2,
#          '0, 1, 7': 1,
#          '4, 7': 1,
#          '1, 4, 7': 3,
#          '0, 3': 1,
#          '1, 3, 4, 5, 7': 2,
#          '3, 7': 2,
#          '1, 3, 4, 7': 2,
#          '3, 4, 5, 7': 3,
#          '2, 4': 4,
#          '5, 6': 1,
#          '1, 2, 3, 5': 4,
#          '1, 3, 5': 3,
#          '1, 2, 34': 1,
#          '1, 2, 4, 5': 4,
#          '0, 05, 2, 27, 7': 1,
#          '1, 3, 7': 2,
#          '3, 4, 7': 2,
#          '1, 2, 3, 4, 7': 1,
#          '10': 1,
#          '0': 1,
#          '1, 2, 3, 7': 1})

# %%
for i, q in enumerate(df['Q1']):
  if int(q) <= 8:
    df.loc[i, 'Score'] = 'Low'
  else:
    df.loc[i, 'Score'] = 'High'
#Создаем новую колонку для фильтрации респондентов по первому вопросу

# %%
#Проверяем тип распределения данных в первой характеристике
statistic, pvalue = stats.shapiro(df['Total Traffic(MB)'])
statistic, pvalue
pvalue < 0.5
# Out:
# False

# %%
import statsmodels.api as st
names = [i for i in df.columns if (i not in ['user_id', 'Q1', 'Q2', 'Score'])]

# %%
for i in names:
  fig = st.qqplot(df[i].values, line='45')
fig.show()
#Распределение не является нормальным

# %%
#Проверяем статистические показатели данных
df['Total Traffic(MB)'].describe()
# Out:
# count    3058.000000
# mean      405.754542
# std       220.475485
# min       100.026680
# 25%       213.006655
# 50%       363.753705
# 75%       572.792975
# max       887.078270
# Name: Total Traffic(MB), dtype: float64

# %%
#Строим бутстрап для проверки альтернативной гипотезы о том, что медианы выборки с высокой оценкой больше медианы выборки с низкой оценкой
def bootstrap_median(s1, s2, n=1500, statistic=np.median, c_level=0.95):
  len_df = max(len(s1), len(s2))
  boot_df = list()
  for i in range(n):
    s1_sample = s1.sample(len_df, replace=True).values
    s2_sample = s2.sample(len_df, replace=True).values
    boot_df.append(statistic(s1_sample) - statistic(s2_sample))

  boot_df = pd.DataFrame(boot_df)

  left_quant = (1 - c_level) / 2
  right_quant = 1 - left_quant
  quantiles = boot_df.quantile([left_quant, right_quant])

  p_value = stats.norm.cdf(x=0, loc=boot_df.mean(), scale=boot_df.std())

  bar_height, x, bars = plt.hist(boot_df, bins=60)

  for bar in bars:
    if bar.get_x() < 0:
      bar.set_facecolor('red')
      bar.set_edgecolor('black')
    else:
      bar.set_facecolor('grey')
      bar.set_edgecolor('black')

  plt.vlines(quantiles, ymin=0, ymax=100, linestyle='--')
  plt.xlabel('value')
  plt.ylabel('count')
  plt.title(f'Bootstrap {s1.name} values histogram')
  plt.show()

  return (boot_df, p_value)

# %%
result_dict = dict()

for i in names:
  temp_df = df[df[i].notnull()]
  s1 = temp_df[temp_df['Score'] == 'High'][i]
  s2 = temp_df[temp_df['Score'] == 'Low'][i]
  result_dict[i] = bootstrap_median(s1, s2)

# %%
for name, i in zip(result_dict, result_dict.values()):
  print(f'{name} p value =', i[1])
  print()

#Статистически значимая разница(pvalue < 5%, 0 не находится в пределах доверительного интервала) наблюдается только у показателя Video Streaming Download Throughput(Kbps))
# Out:
# Total Traffic(MB) p value = [0.83318039]
#
# Downlink Throughput(Kbps) p value = [0.75916952]
#
# Uplink Throughput(Kbps) p value = [0.168061]
#
# Downlink TCP Retransmission Rate(%) p value = [0.06327335]
#
# Video Streaming Download Throughput(Kbps) p value = [0.0291953]
#
# Video Streaming xKB Start Delay(ms) p value = [0.5733806]
#
# Web Page Download Throughput(Kbps) p value = [0.86982427]
#
# Web Average TCP RTT(ms) p value = [0.90087804]

# %%
Counter(df['Q2'])
# Out:
# Counter({nan: 1797,
#          '4': 170,
#          '3': 190,
#          '2, 3, 4': 11,
#          '4, 5': 30,
#          '1, 3, 4': 76,
#          '1, 3, 4, 5': 40,
#          '1, 3': 121,
#          '3, 4': 85,
#          '1, 2': 22,
#          '3, 5': 8,
#          '1': 168,
#          '7': 64,
#          '1, 4': 56,
#          '1, 2, 3, 4, 5': 27,
#          '2, 3': 12,
#          '1, 2, 3, 4': 18,
#          '2, 3, 4, 5': 3,
#          '3, 4, 5': 45,
#          '1, 2, 5': 3,
#          '1, 5': 7,
#          '1, 2, 4': 11,
#          '6': 10,
#          '1, 4, 5': 27,
#          '1, 2, 3': 44,
#          '2, 5': 1,
#          '2, 4, 5': 2,
#          '1, 2, 7': 1,
#          '5': 9,
#          '2': 11,
#          '1, 2, 3, 4, 5, 6': 2,
#          '0, 1, 7': 1,
#          '4, 7': 1,
#          '1, 4, 7': 3,
#          '0, 3': 1,
#          '1, 3, 4, 5, 7': 2,
#          '3, 7': 2,
#          '1, 3, 4, 7': 2,
#          '3, 4, 5, 7': 3,
#          '2, 4': 4,
#          '5, 6': 1,
#          '1, 2, 3, 5': 4,
#          '1, 3, 5': 3,
#          '1, 2, 34': 1,
#          '1, 2, 4, 5': 4,
#          '0, 05, 2, 27, 7': 1,
#          '1, 3, 7': 2,
#          '3, 4, 7': 2,
#          '1, 2, 3, 4, 7': 1,
#          '10': 1,
#          '0': 1,
#          '1, 2, 3, 7': 1})

# %%
df_2 = df
df['bad_call'] = 0
df['bad_time_call'] = 0
df['bad_cell_buliding'] = 0
df['slow_mobile_internet'] = 0
df['slow_video'] = 0
df['idk'] = 0
df['other'] = 0

# %%
#теперь создаем выборки с учетом ответов на второй вопрос:

for i, q in zip(df_2.index, df_2['Q2']):
  if ('1' in str(q)):
    df_2.loc[i, 'bad_call'] = True

  if ('2' in str(q)):
    df_2.loc[i, 'bad_time_call'] = True

  if ('3' in str(q)):
    df_2.loc[i, 'bad_cell_buliding'] = True

  if ('4' in str(q)):
    df_2.loc[i, 'slow_mobile_internet'] = True

  if ('5' in str(q)):
    df_2.loc[i, 'slow_video'] = True

  if ('6' in str(q)):
    df_2.loc[i, 'idk'] = True

  if ('7' in str(q)):
    df_2.loc[i, 'other'] = True

# %%
temp = ['bad_call', 'bad_time_call', 'bad_cell_buliding', 'slow_mobile_internet', 'slow_video', 'idk', 'other']
df_names = df_2[names + temp]
df_names.fillna(0)
df_names.corr()[names].loc[temp]
# Out:
#                       Total Traffic(MB)  Downlink Throughput(Kbps)  \
# bad_call                      -0.012951                  -0.015238
# bad_time_call                 -0.016651                  -0.030103
# bad_cell_buliding             -0.003287                  -0.052228
# slow_mobile_internet           0.021068                  -0.086801
# slow_video                     0.019436                  -0.072391
# idk                            0.020786                   0.030759
# other                         -0.001462                  -0.008988
#
#                       Uplink Throughput(Kbps)  \
# bad_call                            -0.009245
# bad_time_call                       -0.010313
# bad_cell_buliding                   -0.033160
# slow_mobile_internet                -0.051674
# slow_video                          -0.050230
# idk                                 -0.015808
# other                                0.008349
#
#                       Downlink TCP Retransmission Rate(%)  \
# bad_call                                         0.024990
# bad_time_call                                    0.031645
# bad_cell_buliding                                0.028438
# slow_mobile_internet                             0.071223
# slow_video                                       0.072968
# idk                                             -0.008756
# other                                            0.030714
#
#                       Video Streaming Download Throughput(Kbps)  \
# bad_call                                              -0.001801
# bad_time_call                                         -0.006844
# bad_cell_buliding                                     -0.052566
# slow_mobile_internet                                  -0.122932
# slow_video                                            -0.096683
# idk                                                    0.011092
# other                                                 -0.006799
#
#                       Video Streaming xKB Start Delay(ms)  \
# bad_call                                         0.071296
# bad_time_call                                    0.007482
# bad_cell_buliding                                0.039534
# slow_mobile_internet                             0.108248
# slow_video                                       0.034032
# idk                                             -0.006832
# other                                            0.009648
#
#                       Web Page Download Throughput(Kbps)  \
# bad_call                                        0.014524
# bad_time_call                                  -0.031459
# bad_cell_buliding                              -0.022611
# slow_mobile_internet                           -0.068114
# slow_video                                     -0.076874
# idk                                            -0.011553
# other                                          -0.008283
#
#                       Web Average TCP RTT(ms)
# bad_call                             0.018099
# bad_time_call                        0.034135
# bad_cell_buliding                    0.027175
# slow_mobile_internet                 0.129058
# slow_video                           0.086183
# idk                                 -0.010433
# other                                0.014310

# %%
# Видим корреляцию в ответах медленный мобильный интернет и параметрах:
# 'Video Streaming Download Throughput(Kbps)',
#'Video Streaming xKB Start Delay(ms)',
#'Web Average TCP RTT(ms)'

problem_list = ['Video Streaming Download Throughput(Kbps)', 'Video Streaming xKB Start Delay(ms)', 'Web Average TCP RTT(ms)']

# %%
problem_dict = dict()

for i in problem_list:
  temp_df = df_2[df_2[i].notnull()]
  s1 = temp_df[temp_df['Score'] == 'High'][i]
  s2 = temp_df[temp_df['slow_mobile_internet'] == True][i]
  problem_dict[i] = bootstrap_median(s1, s2)

# %%
for name, i in zip(problem_dict, problem_dict.values()):
  print(f'{name} p value =', i[1])

#Видим значимую разницу параметра Video Streaming Download Throughput(Kbps)
# Out:
# Video Streaming Download Throughput(Kbps) p value = [4.60528084e-14]
# Video Streaming xKB Start Delay(ms) p value = [0.9999995]
# Web Average TCP RTT(ms) p value = [0.99999991]
